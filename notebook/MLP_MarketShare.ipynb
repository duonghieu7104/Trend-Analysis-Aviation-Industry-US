# %%
import warnings
warnings.filterwarnings('ignore')

# PySpark - Import specific classes to avoid conflicts
from pyspark.sql import SparkSession
import pyspark.sql.functions as F
from pyspark.sql.functions import col, when, expr
from pyspark.sql.types import *
from pyspark.ml.feature import VectorAssembler, StringIndexer, StandardScaler
from pyspark.ml.regression import (
    RandomForestRegressor as SparkRandomForestRegressor, 
    GBTRegressor as SparkGBTRegressor
)
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml import Pipeline
from pyspark.ml.tuning import ParamGridBuilder, TrainValidationSplit, CrossValidator
from xgboost.spark import SparkXGBRegressor
from pyspark.sql.functions import corr, avg, stddev
from pyspark.ml.classification import MultilayerPerceptronClassifier

# Data processing & ML
import pandas as pd
import numpy as np
from builtins import min as py_min, max as py_max, sum as py_sum


# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.figure_factory as ff

# Model interpretation
import shap

# Time series
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller

# Utilities
import kagglehub
from datetime import datetime
import json
import joblib


from pyspark.ml.feature import VectorAssembler, StringIndexer, StandardScaler
from pyspark.ml import Pipeline
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np

# %%
# Initialize Spark Session with optimized configuration
spark = SparkSession.builder \
    .appName("Enhanced Airline Market Share Prediction 2") \
    .config("spark.driver.memory", "6g") \
    .getOrCreate()

# Set log level to reduce verbosity
spark.sparkContext.setLogLevel("WARN")

# %%
# Download dataset
path = kagglehub.dataset_download("bhavikjikadara/us-airline-flight-routes-and-fares-1993-2024")

# Load data with optimized settings
df = (
    spark.read
    .option("header", "true")
    .option("inferSchema", "true")
    .option("quote", '"')
    .option("escape", '"')
    .option("multiLine", "true")
    .option("mode", "PERMISSIVE")
    .option("nullValue", "")
    .option("nanValue", "NaN")
    .option("emptyValue", "")
    .csv(f"{path}/*.csv")
)

print(f" Shape: {df.count():,} rows × {len(df.columns)} columns")
# Out:
#  Shape: 245,955 rows × 23 columns

# %%
#Remove rows with null target variable
df_clean = df.filter(col('large_ms').isNotNull())
print(df_clean.count())
# Out:
# 244415

# %%
#Filter valid market share values (0-1)
df_clean = df_clean.filter((col('large_ms') >= 0) & (col('large_ms') <= 1))
print(df_clean.count())
# Out:
# 244415

# %%
#Remove invalid business metrics
df_clean = df_clean.filter(
    (col('passengers') > 0) & 
    (col('fare') > 0) & 
    (col('nsmiles') > 0)
)
print(df_clean.count())
# Out:
# 238057

# %%
#Remove rows with missing carrier information
df_clean = df_clean.dropna(subset=['carrier_low'])
print(df_clean.count())
# Out:
# 237985

# %%
#Remove extreme outliers (using IQR method)
numeric_cols = ['passengers', 'fare', 'nsmiles', 'large_ms', 'lf_ms']
for col_name in numeric_cols:
    if col_name in df_clean.columns:
        # Calculate IQR
        quantiles = df_clean.select(
            expr(f"percentile_approx({col_name}, 0.25)").alias("q1"),
            expr(f"percentile_approx({col_name}, 0.75)").alias("q3")
        ).collect()[0]
        
        q1, q3 = quantiles['q1'], quantiles['q3']
        iqr = q3 - q1
        lower_bound = q1 - 1.5 * iqr
        upper_bound = q3 + 1.5 * iqr
        
        df_clean = df_clean.filter(
            (col(col_name) >= lower_bound) & (col(col_name) <= upper_bound)
        )
print(df_clean.count())
# Out:
# 211133

# %%
# Create enhanced features
df_features = df_clean.withColumn(
    'revenue', F.col('passengers') * F.col('fare')
).withColumn(
    'fare_per_mile', F.col('fare') / F.col('nsmiles')
).withColumn(
    'fare_difference', F.col('fare') - F.col('fare_low')
).withColumn(
    'is_largest_cheapest', 
    F.when(F.col('carrier_lg') == F.col('carrier_low'), 1).otherwise(0)
).withColumn(
    'price_competitiveness', 
    F.when(F.col('fare') < F.col('fare_low') * 1.1, 1).otherwise(0)
).withColumn(
    'route_density', F.col('passengers') / F.col('nsmiles')
).withColumn(
    'is_peak_season', 
    F.when(F.col('quarter').isin([2, 3]), 1).otherwise(0)
).withColumn(
    'years_since_2000', F.col('Year') - 2000
).withColumn(
    'fare_elasticity', F.col('fare_difference') / F.col('fare_low')
).withColumn(
    'market_power', 
    F.when(F.col('large_ms') > 0.8, 'Dominant')
    .when(F.col('large_ms') > 0.5, 'Strong')
    .when(F.col('large_ms') > 0.2, 'Moderate')
    .otherwise('Weak')
).withColumn(
    'is_short_haul', F.when(F.col('nsmiles') < 500, 1).otherwise(0)
).withColumn(
    'is_medium_haul', F.when((F.col('nsmiles') >= 500) & (F.col('nsmiles') < 1500), 1).otherwise(0)
).withColumn(
    'is_long_haul', F.when(F.col('nsmiles') >= 1500, 1).otherwise(0)
).withColumn(
    'competition_level',
    F.when(F.col('lf_ms') > 0.8, 'High')
    .when(F.col('lf_ms') > 0.5, 'Medium')
    .otherwise('Low')
)

# Cache để tăng tốc
df_features = df_features.cache()

new_features = [
    'revenue', 'fare_per_mile', 'fare_difference', 'is_largest_cheapest',
    'price_competitiveness', 'route_density', 'is_peak_season', 'years_since_2000',
    'fare_elasticity', 'market_power', 'is_short_haul', 'is_medium_haul', 
    'is_long_haul', 'competition_level'
]

for feature in new_features:
    print(f"  • {feature}")

print(len(df_features.columns))
print(f"{df_features.count():,} rows × {len(df_features.columns)} columns")
# Out:
#   • revenue
#   • fare_per_mile
#   • fare_difference
#   • is_largest_cheapest
#   • price_competitiveness
#   • route_density
#   • is_peak_season
#   • years_since_2000
#   • fare_elasticity
#   • market_power
#   • is_short_haul
#   • is_medium_haul
#   • is_long_haul
#   • competition_level
# 37
# 211,133 rows × 37 columns

# %%
# Define feature columns
numeric_features = [
    'passengers', 'fare', 'nsmiles', 'lf_ms', 'fare_low', 'revenue', 
    'fare_per_mile', 'fare_difference', 'is_largest_cheapest', 'price_competitiveness',
    'route_density', 'is_peak_season', 'years_since_2000', 'fare_elasticity',
    'is_short_haul', 'is_medium_haul', 'is_long_haul', 'Year', 'quarter'
]

categorical_features = ['carrier_lg', 'carrier_low']

# Create string indexers for categorical features
indexers = [
    StringIndexer(inputCol=col, outputCol=col+"_indexed", handleInvalid="keep")
    for col in categorical_features
]

# Feature vector assembly
feature_cols = numeric_features + [col+"_indexed" for col in categorical_features]
assembler = VectorAssembler(
    inputCols=feature_cols,
    outputCol="features_raw"
)

# Feature scaling
scaler = StandardScaler(
    inputCol="features_raw",
    outputCol="features",
    withStd=True,
    withMean=True
)

# Train-test split
train_data, test_data = df_features.randomSplit([0.8, 0.2], seed=42)

print(f"Training set: {train_data.count():,} rows")
print(f"Test set: {test_data.count():,} rows")
print(f"Features: {len(feature_cols)}")
# Out:
# Training set: 168,758 rows
# Test set: 42,375 rows
# Features: 21

# %%
prep_pipeline = Pipeline(stages=indexers + [assembler, scaler])

# %%
prep_model = prep_pipeline.fit(train_data)
train_transformed = prep_model.transform(train_data)
test_transformed = prep_model.transform(test_data)

# %%
def prepare_datasets(train_spark_df, test_spark_df, val_fraction=0.15, batch_size=256):
    """
    Convert Spark DataFrames to TensorFlow datasets
    Returns: train_ds, val_ds, test_ds, and metadata
    """
    # Collect train data
    train_data = train_spark_df.select('features', 'large_ms').collect()
    X_train_full = np.array([row['features'].toArray() for row in train_data])
    y_train_full = np.array([row['large_ms'] for row in train_data])
    
    # Collect test data
    test_data = test_spark_df.select('features', 'large_ms').collect()
    X_test = np.array([row['features'].toArray() for row in test_data])
    y_test = np.array([row['large_ms'] for row in test_data])
    
    # Split train into train and validation
    n_samples = len(X_train_full)
    n_val = int(n_samples * val_fraction)
    
    # Shuffle
    indices = np.random.RandomState(42).permutation(n_samples)
    
    # Split
    val_indices = indices[:n_val]
    train_indices = indices[n_val:]
    
    X_train = X_train_full[train_indices]
    y_train = y_train_full[train_indices]
    X_val = X_train_full[val_indices]
    y_val = y_train_full[val_indices]
    
    # Create TensorFlow datasets
    train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train))
    train_ds = train_ds.shuffle(buffer_size=10000, seed=42).batch(batch_size).prefetch(tf.data.AUTOTUNE)
    
    val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val))
    val_ds = val_ds.batch(batch_size).prefetch(tf.data.AUTOTUNE)
    
    test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test))
    test_ds = test_ds.batch(batch_size).prefetch(tf.data.AUTOTUNE)
    
    metadata = {
        'n_train': len(X_train),
        'n_val': len(X_val),
        'n_test': len(X_test),
        'n_features': X_train.shape[1],
        'X_test': X_test,
        'y_test': y_test
    }
    
    return train_ds, val_ds, test_ds, metadata

# %%
train_dataset, val_dataset, test_dataset, metadata = prepare_datasets(
    train_transformed, 
    test_transformed,
    val_fraction=0.15,
    batch_size=512
)

# %%
n_train = metadata['n_train']
n_val = metadata['n_val']
n_test = metadata['n_test']
n_features = metadata['n_features']

# %%
def create_mlp_model(input_dim):
    """Create MLP regression model"""
    model = keras.Sequential([
        # Input layer
        layers.Input(shape=(input_dim,)),
        
        # Hidden layer 1
        layers.Dense(256, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001)),
        layers.BatchNormalization(),
        layers.Dropout(0.3),
        
        # Hidden layer 2
        layers.Dense(128, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001)),
        layers.BatchNormalization(),
        layers.Dropout(0.3),
        
        # Hidden layer 3
        layers.Dense(64, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001)),
        layers.BatchNormalization(),
        layers.Dropout(0.2),
        
        # Hidden layer 4
        layers.Dense(32, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001)),
        layers.Dropout(0.2),
        
        # Output layer (regression)
        layers.Dense(1, activation='sigmoid')  # sigmoid vì output trong [0,1]
    ])
    
    return model

# %%
mlp_model = create_mlp_model(n_features)

# %%
mlp_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_10 (Dense)            (None, 256)               5632
#
#  batch_normalization_6 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout_8 (Dropout)         (None, 256)               0
#
#  dense_11 (Dense)            (None, 128)               32896
#
#  batch_normalization_7 (Bat  (None, 128)               512
#  chNormalization)
#
#  dropout_9 (Dropout)         (None, 128)               0
#
#  dense_12 (Dense)            (None, 64)                8256
#
#  batch_normalization_8 (Bat  (None, 64)                256
#  chNormalization)
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_13 (Dense)            (None, 32)                2080
#
#  dropout_11 (Dropout)        (None, 32)                0
#
#  dense_14 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 50689 (198.00 KB)
# Trainable params: 49793 (194.50 KB)
# Non-trainable params: 896 (3.50 KB)
# _________________________________________________________________

# %%
mlp_model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss='mse',
    metrics=['mae', 'mse', tf.keras.metrics.RootMeanSquaredError(name='rmse')]
)

# %%
# Callbacks
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=15,
        restore_best_weights=True,
        verbose=1
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        min_lr=1e-6,
        verbose=1
    ),
    keras.callbacks.ModelCheckpoint(
        'best_mlp_model.h5',
        monitor='val_loss',
        save_best_only=True,
        verbose=1
    )
]

# %%
history = mlp_model.fit(
    train_dataset,
    validation_data=val_dataset,  # Sử dụng validation dataset đã chuẩn bị
    epochs=100,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/100
# 278/281 [============================>.] - ETA: 0s - loss: 0.1733 - mae: 0.1123 - mse: 0.0241 - rmse: 0.1553
# Epoch 1: val_loss improved from inf to 0.09153, saving model to best_mlp_model.h5
# 281/281 [==============================] - 6s 15ms/step - loss: 0.1723 - mae: 0.1120 - mse: 0.0240 - rmse: 0.1550 - val_loss: 0.0915 - val_mae: 0.2002 - val_mse: 0.0576 - val_rmse: 0.2399 - lr: 0.0010
# Epoch 2/100
# 278/281 [============================>.] - ETA: 0s - loss: 0.0235 - mae: 0.0720 - mse: 0.0104 - rmse: 0.1018
# Epoch 2: val_loss improved from 0.09153 to 0.04484, saving model to best_mlp_model.h5
# 281/281 [==============================] - 4s 13ms/step - loss: 0.0235 - mae: 0.0719 - mse: 0.0104 - rmse: 0.1017 - val_loss: 0.0448 - val_mae: 0.1713 - val_mse: 0.0407 - val_rmse: 0.2017 - lr: 0.0010
# Epoch 3/100
# 276/281 [============================>.] - ETA: 0s - loss: 0.0118 - mae: 0.0666 - mse: 0.0091 - rmse: 0.0955
# Epoch 3: val_loss improved from 0.04484 to 0.01113, saving model to best_mlp_model.h5
# 281/281 [==============================] - 3s 12ms/step - loss: 0.0118 - mae: 0.0667 - mse: 0.0091 - rmse: 0.0955 - val_loss: 0.0111 - val_mae: 0.0700 - val_mse: 0.0092 - val_rmse: 0.0957 - lr: 0.0010
# Epoch 4/100
# 281/281 [==============================] - ETA: 0s - loss: 0.0106 - mae: 0.0653 - mse: 0.0088 - rmse: 0.0941
# Epoch 4: val_loss improved from 0.01113 to 0.00997, saving model to best_mlp_model.h5
# 281/281 [==============================] - 3s 12ms/step - loss: 0.0106 - mae: 0.0653 - mse: 0.0088 - rmse: 0.0941 - val_loss: 0.0100 - val_mae: 0.0633 - val_mse: 0.0083 - val_rmse: 0.0914 - lr: 0.0010
# Epoch 5/100
# 278/281 [============================>.] - ETA: 0s - loss: 0.0104 - mae: 0.0650 - mse: 0.0088 - rmse: 0.0936
# Epoch 5: val_loss did not improve from 0.00997
# 281/281 [==============================] - 3s 12ms/step - loss: 0.0104 - mae: 0.0650 - mse: 0.0088 - rmse: 0.0936 - val_loss: 0.0100 - val_mae: 0.0600 - val_mse: 0.0083 - val_rmse: 0.0912 - lr: 0.0010
# Epoch 6/100
# 281/281 [==============================] - ETA: 0s - loss: 0.0103 - mae: 0.0648 - mse: 0.0087 - rmse: 0.0934
# Epoch 6: val_loss improved from 0.00997 to 0.00938, saving model to best_mlp_model.h5
# 281/281 [==============================] - 4s 13ms/step - loss: 0.0103 - mae: 0.0648 - mse: 0.0087 - rmse: 0.0934 - val_loss: 0.0094 - val_mae: 0.0581 - val_mse: 0.0078 - val_rmse: 0.0886 - lr: 0.0010
# Epoch 7/100
# 277/281 [============================>.] - ETA: 0s - loss: 0.0101 - mae: 0.0642 - mse: 0.0086 - rmse: 0.0928
# Epoch 7: val_loss improved from 0.00938 to 0.00923, saving model to best_mlp_model.h5
# 281/281 [==============================] - 3s 12ms/step - loss: 0.0101 - mae: 0.0643 - mse: 0.0086 - rmse: 0.0928 - val_loss: 0.0092 - val_mae: 0.0586 - val_mse: 0.0078 - val_rmse: 0.0881 - lr: 0.0010
# Epoch 8/100
# 279/281 [============================>.] - ETA: 0s - loss: 0.0101 - mae: 0.0643 - mse: 0.0086 - rmse: 0.0928
# Epoch 8: val_loss did not improve from 0.00923
# 281/281 [==============================] - 3s 12ms/step - loss: 0.0101 - mae: 0.0643 - mse: 0.0086 - rmse: 0.0928 - val_loss: 0.0100 - val_mae: 0.0647 - val_mse: 0.0085 - val_rmse: 0.0923 - lr: 0.0010
# Epoch 9/100
# 278/281 [============================>.] - ETA: 0s - loss: 0.0101 - mae: 0.0644 - mse: 0.0086 - rmse: 0.0930
# Epoch 9: val_loss did not improve from 0.00923
# 281/281 [==============================] - 3s 11ms/step - loss: 0.0101 - mae: 0.0644 - mse: 0.0086 - rmse: 0.0929 - val_loss: 0.0099 - val_mae: 0.0669 - val_mse: 0.0085 - val_rmse: 0.0924 - lr: 0.0010
# Epoch 10/100
# 275/281 [============================>.] - ETA: 0s - loss: 0.0101 - mae: 0.0642 - mse: 0.0086 - rmse: 0.0929
# Epoch 10: val_loss did not improve from 0.00923
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0101 - mae: 0.0642 - mse: 0.0086 - rmse: 0.0928 - val_loss: 0.0105 - val_mae: 0.0631 - val_mse: 0.0091 - val_rmse: 0.0953 - lr: 0.0010
# Epoch 11/100
# 275/281 [============================>.] - ETA: 0s - loss: 0.0100 - mae: 0.0646 - mse: 0.0087 - rmse: 0.0930
# Epoch 11: val_loss did not improve from 0.00923
# 281/281 [==============================] - 2s 6ms/step - loss: 0.0100 - mae: 0.0645 - mse: 0.0087 - rmse: 0.0930 - val_loss: 0.0093 - val_mae: 0.0622 - val_mse: 0.0079 - val_rmse: 0.0887 - lr: 0.0010
# Epoch 12/100
# 280/281 [============================>.] - ETA: 0s - loss: 0.0100 - mae: 0.0642 - mse: 0.0086 - rmse: 0.0928
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 12: val_loss did not improve from 0.00923
# 281/281 [==============================] - 2s 6ms/step - loss: 0.0100 - mae: 0.0642 - mse: 0.0086 - rmse: 0.0928 - val_loss: 0.0100 - val_mae: 0.0674 - val_mse: 0.0086 - val_rmse: 0.0928 - lr: 0.0010
# Epoch 13/100
# 277/281 [============================>.] - ETA: 0s - loss: 0.0093 - mae: 0.0618 - mse: 0.0081 - rmse: 0.0901
# Epoch 13: val_loss improved from 0.00923 to 0.00843, saving model to best_mlp_model.h5
# 281/281 [==============================] - 2s 6ms/step - loss: 0.0093 - mae: 0.0618 - mse: 0.0081 - rmse: 0.0900 - val_loss: 0.0084 - val_mae: 0.0520 - val_mse: 0.0073 - val_rmse: 0.0857 - lr: 5.0000e-04
# Epoch 14/100
# 277/281 [============================>.] - ETA: 0s - loss: 0.0092 - mae: 0.0619 - mse: 0.0081 - rmse: 0.0900
# Epoch 14: val_loss improved from 0.00843 to 0.00799, saving model to best_mlp_model.h5
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0092 - mae: 0.0619 - mse: 0.0081 - rmse: 0.0901 - val_loss: 0.0080 - val_mae: 0.0541 - val_mse: 0.0069 - val_rmse: 0.0833 - lr: 5.0000e-04
# Epoch 15/100
# 277/281 [============================>.] - ETA: 0s - loss: 0.0091 - mae: 0.0615 - mse: 0.0080 - rmse: 0.0897
# Epoch 15: val_loss did not improve from 0.00799
# 281/281 [==============================] - 2s 6ms/step - loss: 0.0091 - mae: 0.0615 - mse: 0.0080 - rmse: 0.0897 - val_loss: 0.0082 - val_mae: 0.0565 - val_mse: 0.0072 - val_rmse: 0.0848 - lr: 5.0000e-04
# Epoch 16/100
# 272/281 [============================>.] - ETA: 0s - loss: 0.0091 - mae: 0.0618 - mse: 0.0081 - rmse: 0.0899
# Epoch 16: val_loss did not improve from 0.00799
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0091 - mae: 0.0618 - mse: 0.0081 - rmse: 0.0898 - val_loss: 0.0083 - val_mae: 0.0588 - val_mse: 0.0073 - val_rmse: 0.0854 - lr: 5.0000e-04
# Epoch 17/100
# 280/281 [============================>.] - ETA: 0s - loss: 0.0090 - mae: 0.0615 - mse: 0.0081 - rmse: 0.0897
# Epoch 17: val_loss did not improve from 0.00799
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0090 - mae: 0.0616 - mse: 0.0081 - rmse: 0.0898 - val_loss: 0.0080 - val_mae: 0.0529 - val_mse: 0.0070 - val_rmse: 0.0838 - lr: 5.0000e-04
# Epoch 18/100
# 277/281 [============================>.] - ETA: 0s - loss: 0.0090 - mae: 0.0613 - mse: 0.0080 - rmse: 0.0895
# Epoch 18: val_loss did not improve from 0.00799
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0090 - mae: 0.0613 - mse: 0.0080 - rmse: 0.0895 - val_loss: 0.0080 - val_mae: 0.0557 - val_mse: 0.0070 - val_rmse: 0.0838 - lr: 5.0000e-04
# Epoch 19/100
# 278/281 [============================>.] - ETA: 0s - loss: 0.0090 - mae: 0.0614 - mse: 0.0080 - rmse: 0.0894
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 19: val_loss did not improve from 0.00799
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0090 - mae: 0.0614 - mse: 0.0080 - rmse: 0.0895 - val_loss: 0.0083 - val_mae: 0.0586 - val_mse: 0.0074 - val_rmse: 0.0858 - lr: 5.0000e-04
# Epoch 20/100
# 278/281 [============================>.] - ETA: 0s - loss: 0.0086 - mae: 0.0596 - mse: 0.0077 - rmse: 0.0876
# Epoch 20: val_loss improved from 0.00799 to 0.00750, saving model to best_mlp_model.h5
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0086 - mae: 0.0596 - mse: 0.0077 - rmse: 0.0876 - val_loss: 0.0075 - val_mae: 0.0517 - val_mse: 0.0067 - val_rmse: 0.0816 - lr: 2.5000e-04
# Epoch 21/100
# 277/281 [============================>.] - ETA: 0s - loss: 0.0085 - mae: 0.0595 - mse: 0.0077 - rmse: 0.0876
# Epoch 21: val_loss improved from 0.00750 to 0.00744, saving model to best_mlp_model.h5
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0085 - mae: 0.0595 - mse: 0.0077 - rmse: 0.0875 - val_loss: 0.0074 - val_mae: 0.0520 - val_mse: 0.0066 - val_rmse: 0.0815 - lr: 2.5000e-04
# Epoch 22/100
# 274/281 [============================>.] - ETA: 0s - loss: 0.0084 - mae: 0.0592 - mse: 0.0076 - rmse: 0.0873
# Epoch 22: val_loss did not improve from 0.00744
# 281/281 [==============================] - 2s 6ms/step - loss: 0.0084 - mae: 0.0592 - mse: 0.0076 - rmse: 0.0873 - val_loss: 0.0079 - val_mae: 0.0586 - val_mse: 0.0071 - val_rmse: 0.0845 - lr: 2.5000e-04
# Epoch 23/100
# 274/281 [============================>.] - ETA: 0s - loss: 0.0084 - mae: 0.0592 - mse: 0.0076 - rmse: 0.0874
# Epoch 23: val_loss improved from 0.00744 to 0.00743, saving model to best_mlp_model.h5
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0084 - mae: 0.0592 - mse: 0.0076 - rmse: 0.0873 - val_loss: 0.0074 - val_mae: 0.0515 - val_mse: 0.0067 - val_rmse: 0.0816 - lr: 2.5000e-04
# Epoch 24/100
# 281/281 [==============================] - ETA: 0s - loss: 0.0084 - mae: 0.0591 - mse: 0.0076 - rmse: 0.0871
# Epoch 24: val_loss improved from 0.00743 to 0.00737, saving model to best_mlp_model.h5
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0084 - mae: 0.0591 - mse: 0.0076 - rmse: 0.0871 - val_loss: 0.0074 - val_mae: 0.0496 - val_mse: 0.0066 - val_rmse: 0.0813 - lr: 2.5000e-04
# Epoch 25/100
# 275/281 [============================>.] - ETA: 0s - loss: 0.0084 - mae: 0.0591 - mse: 0.0076 - rmse: 0.0872
# Epoch 25: val_loss improved from 0.00737 to 0.00724, saving model to best_mlp_model.h5
# 281/281 [==============================] - 2s 6ms/step - loss: 0.0084 - mae: 0.0591 - mse: 0.0076 - rmse: 0.0872 - val_loss: 0.0072 - val_mae: 0.0490 - val_mse: 0.0065 - val_rmse: 0.0805 - lr: 2.5000e-04
# Epoch 26/100
# 277/281 [============================>.] - ETA: 0s - loss: 0.0083 - mae: 0.0589 - mse: 0.0076 - rmse: 0.0870
# Epoch 26: val_loss did not improve from 0.00724
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0083 - mae: 0.0588 - mse: 0.0076 - rmse: 0.0870 - val_loss: 0.0073 - val_mae: 0.0504 - val_mse: 0.0066 - val_rmse: 0.0812 - lr: 2.5000e-04
# Epoch 27/100
# 280/281 [============================>.] - ETA: 0s - loss: 0.0083 - mae: 0.0587 - mse: 0.0075 - rmse: 0.0869
# Epoch 27: val_loss improved from 0.00724 to 0.00723, saving model to best_mlp_model.h5
# 281/281 [==============================] - 2s 6ms/step - loss: 0.0083 - mae: 0.0587 - mse: 0.0075 - rmse: 0.0869 - val_loss: 0.0072 - val_mae: 0.0489 - val_mse: 0.0065 - val_rmse: 0.0805 - lr: 2.5000e-04
# Epoch 28/100
# 274/281 [============================>.] - ETA: 0s - loss: 0.0083 - mae: 0.0588 - mse: 0.0075 - rmse: 0.0868
# Epoch 28: val_loss did not improve from 0.00723
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0083 - mae: 0.0589 - mse: 0.0076 - rmse: 0.0869 - val_loss: 0.0073 - val_mae: 0.0494 - val_mse: 0.0065 - val_rmse: 0.0809 - lr: 2.5000e-04
# Epoch 29/100
# 278/281 [============================>.] - ETA: 0s - loss: 0.0082 - mae: 0.0584 - mse: 0.0075 - rmse: 0.0865
# Epoch 29: val_loss did not improve from 0.00723
# 281/281 [==============================] - 2s 6ms/step - loss: 0.0082 - mae: 0.0584 - mse: 0.0075 - rmse: 0.0865 - val_loss: 0.0073 - val_mae: 0.0513 - val_mse: 0.0066 - val_rmse: 0.0810 - lr: 2.5000e-04
# Epoch 30/100
# 279/281 [============================>.] - ETA: 0s - loss: 0.0083 - mae: 0.0587 - mse: 0.0075 - rmse: 0.0868
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 30: val_loss did not improve from 0.00723
# 281/281 [==============================] - 2s 6ms/step - loss: 0.0083 - mae: 0.0587 - mse: 0.0075 - rmse: 0.0868 - val_loss: 0.0072 - val_mae: 0.0496 - val_mse: 0.0065 - val_rmse: 0.0808 - lr: 2.5000e-04
# Epoch 31/100
# 274/281 [============================>.] - ETA: 0s - loss: 0.0080 - mae: 0.0573 - mse: 0.0073 - rmse: 0.0854
# Epoch 31: val_loss improved from 0.00723 to 0.00700, saving model to best_mlp_model.h5
# 281/281 [==============================] - 2s 6ms/step - loss: 0.0080 - mae: 0.0573 - mse: 0.0073 - rmse: 0.0854 - val_loss: 0.0070 - val_mae: 0.0484 - val_mse: 0.0063 - val_rmse: 0.0795 - lr: 1.2500e-04
# Epoch 32/100
# 276/281 [============================>.] - ETA: 0s - loss: 0.0080 - mae: 0.0572 - mse: 0.0073 - rmse: 0.0854
# Epoch 32: val_loss did not improve from 0.00700
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0080 - mae: 0.0572 - mse: 0.0073 - rmse: 0.0854 - val_loss: 0.0070 - val_mae: 0.0477 - val_mse: 0.0063 - val_rmse: 0.0796 - lr: 1.2500e-04
# Epoch 33/100
# 276/281 [============================>.] - ETA: 0s - loss: 0.0079 - mae: 0.0570 - mse: 0.0072 - rmse: 0.0851
# Epoch 33: val_loss did not improve from 0.00700
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0079 - mae: 0.0570 - mse: 0.0072 - rmse: 0.0851 - val_loss: 0.0071 - val_mae: 0.0510 - val_mse: 0.0064 - val_rmse: 0.0802 - lr: 1.2500e-04
# Epoch 34/100
# 276/281 [============================>.] - ETA: 0s - loss: 0.0078 - mae: 0.0567 - mse: 0.0072 - rmse: 0.0848
# Epoch 34: val_loss improved from 0.00700 to 0.00693, saving model to best_mlp_model.h5
# 281/281 [==============================] - 2s 6ms/step - loss: 0.0078 - mae: 0.0567 - mse: 0.0072 - rmse: 0.0848 - val_loss: 0.0069 - val_mae: 0.0473 - val_mse: 0.0063 - val_rmse: 0.0793 - lr: 1.2500e-04
# Epoch 35/100
# 281/281 [==============================] - ETA: 0s - loss: 0.0079 - mae: 0.0569 - mse: 0.0072 - rmse: 0.0850
# Epoch 35: val_loss did not improve from 0.00693
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0079 - mae: 0.0569 - mse: 0.0072 - rmse: 0.0850 - val_loss: 0.0070 - val_mae: 0.0492 - val_mse: 0.0064 - val_rmse: 0.0801 - lr: 1.2500e-04
# Epoch 36/100
# 281/281 [==============================] - ETA: 0s - loss: 0.0079 - mae: 0.0569 - mse: 0.0072 - rmse: 0.0851
# Epoch 36: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 36: val_loss did not improve from 0.00693
# 281/281 [==============================] - 2s 6ms/step - loss: 0.0079 - mae: 0.0569 - mse: 0.0072 - rmse: 0.0851 - val_loss: 0.0071 - val_mae: 0.0521 - val_mse: 0.0065 - val_rmse: 0.0806 - lr: 1.2500e-04
# Epoch 37/100
# 272/281 [============================>.] - ETA: 0s - loss: 0.0077 - mae: 0.0561 - mse: 0.0071 - rmse: 0.0841
# Epoch 37: val_loss improved from 0.00693 to 0.00681, saving model to best_mlp_model.h5
# 281/281 [==============================] - 2s 6ms/step - loss: 0.0077 - mae: 0.0561 - mse: 0.0071 - rmse: 0.0841 - val_loss: 0.0068 - val_mae: 0.0477 - val_mse: 0.0062 - val_rmse: 0.0786 - lr: 6.2500e-05
# Epoch 38/100
# 272/281 [============================>.] - ETA: 0s - loss: 0.0077 - mae: 0.0559 - mse: 0.0071 - rmse: 0.0841
# Epoch 38: val_loss did not improve from 0.00681
# 281/281 [==============================] - 2s 6ms/step - loss: 0.0077 - mae: 0.0559 - mse: 0.0071 - rmse: 0.0841 - val_loss: 0.0068 - val_mae: 0.0472 - val_mse: 0.0062 - val_rmse: 0.0787 - lr: 6.2500e-05
# Epoch 39/100
# 278/281 [============================>.] - ETA: 0s - loss: 0.0076 - mae: 0.0557 - mse: 0.0070 - rmse: 0.0838
# Epoch 39: val_loss did not improve from 0.00681
# 281/281 [==============================] - 2s 6ms/step - loss: 0.0076 - mae: 0.0558 - mse: 0.0070 - rmse: 0.0838 - val_loss: 0.0068 - val_mae: 0.0479 - val_mse: 0.0062 - val_rmse: 0.0790 - lr: 6.2500e-05
# Epoch 40/100
# 274/281 [============================>.] - ETA: 0s - loss: 0.0076 - mae: 0.0556 - mse: 0.0070 - rmse: 0.0837
# Epoch 40: val_loss improved from 0.00681 to 0.00673, saving model to best_mlp_model.h5
# 281/281 [==============================] - 2s 6ms/step - loss: 0.0076 - mae: 0.0556 - mse: 0.0070 - rmse: 0.0838 - val_loss: 0.0067 - val_mae: 0.0463 - val_mse: 0.0061 - val_rmse: 0.0783 - lr: 6.2500e-05
# Epoch 41/100
# 276/281 [============================>.] - ETA: 0s - loss: 0.0076 - mae: 0.0559 - mse: 0.0070 - rmse: 0.0839
# Epoch 41: val_loss did not improve from 0.00673
# 281/281 [==============================] - 2s 6ms/step - loss: 0.0076 - mae: 0.0559 - mse: 0.0070 - rmse: 0.0839 - val_loss: 0.0068 - val_mae: 0.0469 - val_mse: 0.0062 - val_rmse: 0.0788 - lr: 6.2500e-05
# Epoch 42/100
# 277/281 [============================>.] - ETA: 0s - loss: 0.0076 - mae: 0.0557 - mse: 0.0070 - rmse: 0.0838
# Epoch 42: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 42: val_loss did not improve from 0.00673
# 281/281 [==============================] - 2s 6ms/step - loss: 0.0076 - mae: 0.0557 - mse: 0.0070 - rmse: 0.0838 - val_loss: 0.0068 - val_mae: 0.0485 - val_mse: 0.0062 - val_rmse: 0.0787 - lr: 6.2500e-05
# Epoch 43/100
# 276/281 [============================>.] - ETA: 0s - loss: 0.0075 - mae: 0.0553 - mse: 0.0069 - rmse: 0.0834
# Epoch 43: val_loss improved from 0.00673 to 0.00670, saving model to best_mlp_model.h5
# 281/281 [==============================] - 2s 6ms/step - loss: 0.0075 - mae: 0.0553 - mse: 0.0069 - rmse: 0.0833 - val_loss: 0.0067 - val_mae: 0.0473 - val_mse: 0.0061 - val_rmse: 0.0782 - lr: 3.1250e-05
# Epoch 44/100
# 276/281 [============================>.] - ETA: 0s - loss: 0.0075 - mae: 0.0550 - mse: 0.0069 - rmse: 0.0831
# Epoch 44: val_loss improved from 0.00670 to 0.00668, saving model to best_mlp_model.h5
# 281/281 [==============================] - 2s 6ms/step - loss: 0.0075 - mae: 0.0551 - mse: 0.0069 - rmse: 0.0831 - val_loss: 0.0067 - val_mae: 0.0464 - val_mse: 0.0061 - val_rmse: 0.0781 - lr: 3.1250e-05
# Epoch 45/100
# 273/281 [============================>.] - ETA: 0s - loss: 0.0075 - mae: 0.0549 - mse: 0.0069 - rmse: 0.0831
# Epoch 45: val_loss did not improve from 0.00668
# 281/281 [==============================] - 2s 6ms/step - loss: 0.0075 - mae: 0.0550 - mse: 0.0069 - rmse: 0.0831 - val_loss: 0.0067 - val_mae: 0.0463 - val_mse: 0.0061 - val_rmse: 0.0782 - lr: 3.1250e-05
# Epoch 46/100
# 279/281 [============================>.] - ETA: 0s - loss: 0.0075 - mae: 0.0550 - mse: 0.0069 - rmse: 0.0832
# Epoch 46: val_loss did not improve from 0.00668
# 281/281 [==============================] - 2s 6ms/step - loss: 0.0075 - mae: 0.0551 - mse: 0.0069 - rmse: 0.0832 - val_loss: 0.0067 - val_mae: 0.0461 - val_mse: 0.0061 - val_rmse: 0.0781 - lr: 3.1250e-05
# Epoch 47/100
# 278/281 [============================>.] - ETA: 0s - loss: 0.0075 - mae: 0.0550 - mse: 0.0069 - rmse: 0.0830
# Epoch 47: val_loss did not improve from 0.00668
# 281/281 [==============================] - 2s 6ms/step - loss: 0.0075 - mae: 0.0550 - mse: 0.0069 - rmse: 0.0830 - val_loss: 0.0067 - val_mae: 0.0467 - val_mse: 0.0061 - val_rmse: 0.0782 - lr: 3.1250e-05
# Epoch 48/100
# 276/281 [============================>.] - ETA: 0s - loss: 0.0075 - mae: 0.0550 - mse: 0.0069 - rmse: 0.0832
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 48: val_loss improved from 0.00668 to 0.00666, saving model to best_mlp_model.h5
# 281/281 [==============================] - 2s 6ms/step - loss: 0.0075 - mae: 0.0551 - mse: 0.0069 - rmse: 0.0832 - val_loss: 0.0067 - val_mae: 0.0468 - val_mse: 0.0061 - val_rmse: 0.0781 - lr: 3.1250e-05
# Epoch 49/100
# 278/281 [============================>.] - ETA: 0s - loss: 0.0075 - mae: 0.0551 - mse: 0.0069 - rmse: 0.0830
# Epoch 49: val_loss improved from 0.00666 to 0.00663, saving model to best_mlp_model.h5
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0075 - mae: 0.0551 - mse: 0.0069 - rmse: 0.0830 - val_loss: 0.0066 - val_mae: 0.0458 - val_mse: 0.0061 - val_rmse: 0.0778 - lr: 1.5625e-05
# Epoch 50/100
# 279/281 [============================>.] - ETA: 0s - loss: 0.0074 - mae: 0.0548 - mse: 0.0068 - rmse: 0.0827
# Epoch 50: val_loss improved from 0.00663 to 0.00661, saving model to best_mlp_model.h5
# 281/281 [==============================] - 2s 6ms/step - loss: 0.0074 - mae: 0.0548 - mse: 0.0068 - rmse: 0.0827 - val_loss: 0.0066 - val_mae: 0.0452 - val_mse: 0.0060 - val_rmse: 0.0777 - lr: 1.5625e-05
# Epoch 51/100
# 279/281 [============================>.] - ETA: 0s - loss: 0.0074 - mae: 0.0547 - mse: 0.0069 - rmse: 0.0828
# Epoch 51: val_loss did not improve from 0.00661
# 281/281 [==============================] - 2s 6ms/step - loss: 0.0074 - mae: 0.0547 - mse: 0.0069 - rmse: 0.0828 - val_loss: 0.0066 - val_mae: 0.0456 - val_mse: 0.0061 - val_rmse: 0.0778 - lr: 1.5625e-05
# Epoch 52/100
# 272/281 [============================>.] - ETA: 0s - loss: 0.0074 - mae: 0.0549 - mse: 0.0069 - rmse: 0.0829
# Epoch 52: val_loss did not improve from 0.00661
# 281/281 [==============================] - 2s 6ms/step - loss: 0.0074 - mae: 0.0549 - mse: 0.0069 - rmse: 0.0829 - val_loss: 0.0066 - val_mae: 0.0460 - val_mse: 0.0061 - val_rmse: 0.0778 - lr: 1.5625e-05
# Epoch 53/100
# 273/281 [============================>.] - ETA: 0s - loss: 0.0074 - mae: 0.0547 - mse: 0.0068 - rmse: 0.0827
# Epoch 53: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 53: val_loss improved from 0.00661 to 0.00660, saving model to best_mlp_model.h5
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0074 - mae: 0.0547 - mse: 0.0068 - rmse: 0.0827 - val_loss: 0.0066 - val_mae: 0.0454 - val_mse: 0.0060 - val_rmse: 0.0777 - lr: 1.5625e-05
# Epoch 54/100
# 275/281 [============================>.] - ETA: 0s - loss: 0.0074 - mae: 0.0546 - mse: 0.0068 - rmse: 0.0825
# Epoch 54: val_loss did not improve from 0.00660
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0074 - mae: 0.0546 - mse: 0.0068 - rmse: 0.0825 - val_loss: 0.0066 - val_mae: 0.0455 - val_mse: 0.0060 - val_rmse: 0.0777 - lr: 7.8125e-06
# Epoch 55/100
# 278/281 [============================>.] - ETA: 0s - loss: 0.0074 - mae: 0.0546 - mse: 0.0068 - rmse: 0.0827
# Epoch 55: val_loss did not improve from 0.00660
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0074 - mae: 0.0546 - mse: 0.0068 - rmse: 0.0827 - val_loss: 0.0066 - val_mae: 0.0455 - val_mse: 0.0060 - val_rmse: 0.0777 - lr: 7.8125e-06
# Epoch 56/100
# 281/281 [==============================] - ETA: 0s - loss: 0.0074 - mae: 0.0545 - mse: 0.0068 - rmse: 0.0825
# Epoch 56: val_loss did not improve from 0.00660
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0074 - mae: 0.0545 - mse: 0.0068 - rmse: 0.0825 - val_loss: 0.0066 - val_mae: 0.0459 - val_mse: 0.0061 - val_rmse: 0.0778 - lr: 7.8125e-06
# Epoch 57/100
# 278/281 [============================>.] - ETA: 0s - loss: 0.0074 - mae: 0.0545 - mse: 0.0068 - rmse: 0.0825
# Epoch 57: val_loss did not improve from 0.00660
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0074 - mae: 0.0545 - mse: 0.0068 - rmse: 0.0824 - val_loss: 0.0066 - val_mae: 0.0454 - val_mse: 0.0060 - val_rmse: 0.0777 - lr: 7.8125e-06
# Epoch 58/100
# 279/281 [============================>.] - ETA: 0s - loss: 0.0074 - mae: 0.0544 - mse: 0.0068 - rmse: 0.0824
# Epoch 58: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
#
# Epoch 58: val_loss did not improve from 0.00660
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0074 - mae: 0.0544 - mse: 0.0068 - rmse: 0.0824 - val_loss: 0.0066 - val_mae: 0.0458 - val_mse: 0.0060 - val_rmse: 0.0777 - lr: 7.8125e-06
# Epoch 59/100
# 278/281 [============================>.] - ETA: 0s - loss: 0.0074 - mae: 0.0546 - mse: 0.0068 - rmse: 0.0827
# Epoch 59: val_loss improved from 0.00660 to 0.00660, saving model to best_mlp_model.h5
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0074 - mae: 0.0546 - mse: 0.0068 - rmse: 0.0827 - val_loss: 0.0066 - val_mae: 0.0451 - val_mse: 0.0060 - val_rmse: 0.0777 - lr: 3.9063e-06
# Epoch 60/100
# 277/281 [============================>.] - ETA: 0s - loss: 0.0073 - mae: 0.0544 - mse: 0.0068 - rmse: 0.0824
# Epoch 60: val_loss did not improve from 0.00660
# 281/281 [==============================] - 3s 11ms/step - loss: 0.0074 - mae: 0.0544 - mse: 0.0068 - rmse: 0.0824 - val_loss: 0.0066 - val_mae: 0.0456 - val_mse: 0.0060 - val_rmse: 0.0777 - lr: 3.9063e-06
# Epoch 61/100
# 278/281 [============================>.] - ETA: 0s - loss: 0.0074 - mae: 0.0544 - mse: 0.0068 - rmse: 0.0825
# Epoch 61: val_loss did not improve from 0.00660
# 281/281 [==============================] - 4s 13ms/step - loss: 0.0074 - mae: 0.0544 - mse: 0.0068 - rmse: 0.0825 - val_loss: 0.0066 - val_mae: 0.0452 - val_mse: 0.0060 - val_rmse: 0.0777 - lr: 3.9063e-06
# Epoch 62/100
# 280/281 [============================>.] - ETA: 0s - loss: 0.0074 - mae: 0.0544 - mse: 0.0068 - rmse: 0.0825
# Epoch 62: val_loss improved from 0.00660 to 0.00659, saving model to best_mlp_model.h5
# 281/281 [==============================] - 4s 13ms/step - loss: 0.0074 - mae: 0.0544 - mse: 0.0068 - rmse: 0.0824 - val_loss: 0.0066 - val_mae: 0.0455 - val_mse: 0.0060 - val_rmse: 0.0777 - lr: 3.9063e-06
# Epoch 63/100
# 277/281 [============================>.] - ETA: 0s - loss: 0.0074 - mae: 0.0546 - mse: 0.0068 - rmse: 0.0826
# Epoch 63: val_loss did not improve from 0.00659
# 281/281 [==============================] - 4s 13ms/step - loss: 0.0074 - mae: 0.0546 - mse: 0.0068 - rmse: 0.0826 - val_loss: 0.0066 - val_mae: 0.0456 - val_mse: 0.0060 - val_rmse: 0.0777 - lr: 3.9063e-06
# Epoch 64/100
# 279/281 [============================>.] - ETA: 0s - loss: 0.0074 - mae: 0.0544 - mse: 0.0068 - rmse: 0.0824
# Epoch 64: val_loss did not improve from 0.00659
# 281/281 [==============================] - 4s 12ms/step - loss: 0.0074 - mae: 0.0545 - mse: 0.0068 - rmse: 0.0825 - val_loss: 0.0066 - val_mae: 0.0453 - val_mse: 0.0060 - val_rmse: 0.0777 - lr: 3.9063e-06
# Epoch 65/100
# 279/281 [============================>.] - ETA: 0s - loss: 0.0074 - mae: 0.0545 - mse: 0.0068 - rmse: 0.0825
# Epoch 65: val_loss did not improve from 0.00659
# 281/281 [==============================] - 4s 12ms/step - loss: 0.0074 - mae: 0.0545 - mse: 0.0068 - rmse: 0.0826 - val_loss: 0.0066 - val_mae: 0.0454 - val_mse: 0.0060 - val_rmse: 0.0777 - lr: 3.9063e-06
# Epoch 66/100
# 279/281 [============================>.] - ETA: 0s - loss: 0.0073 - mae: 0.0544 - mse: 0.0068 - rmse: 0.0824
# Epoch 66: val_loss did not improve from 0.00659
# 281/281 [==============================] - 4s 13ms/step - loss: 0.0073 - mae: 0.0544 - mse: 0.0068 - rmse: 0.0823 - val_loss: 0.0066 - val_mae: 0.0454 - val_mse: 0.0060 - val_rmse: 0.0777 - lr: 3.9063e-06
# Epoch 67/100
# 276/281 [============================>.] - ETA: 0s - loss: 0.0073 - mae: 0.0543 - mse: 0.0068 - rmse: 0.0824
# Epoch 67: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
#
# Epoch 67: val_loss improved from 0.00659 to 0.00659, saving model to best_mlp_model.h5
# 281/281 [==============================] - 4s 13ms/step - loss: 0.0073 - mae: 0.0544 - mse: 0.0068 - rmse: 0.0824 - val_loss: 0.0066 - val_mae: 0.0452 - val_mse: 0.0060 - val_rmse: 0.0777 - lr: 3.9063e-06
# Epoch 68/100
# 277/281 [============================>.] - ETA: 0s - loss: 0.0074 - mae: 0.0544 - mse: 0.0068 - rmse: 0.0824
# Epoch 68: val_loss did not improve from 0.00659
# 281/281 [==============================] - 3s 12ms/step - loss: 0.0074 - mae: 0.0544 - mse: 0.0068 - rmse: 0.0824 - val_loss: 0.0066 - val_mae: 0.0453 - val_mse: 0.0060 - val_rmse: 0.0777 - lr: 1.9531e-06
# Epoch 69/100
# 276/281 [============================>.] - ETA: 0s - loss: 0.0074 - mae: 0.0545 - mse: 0.0068 - rmse: 0.0825
# Epoch 69: val_loss did not improve from 0.00659
# 281/281 [==============================] - 4s 12ms/step - loss: 0.0074 - mae: 0.0545 - mse: 0.0068 - rmse: 0.0824 - val_loss: 0.0066 - val_mae: 0.0453 - val_mse: 0.0060 - val_rmse: 0.0777 - lr: 1.9531e-06
# Epoch 70/100
# 279/281 [============================>.] - ETA: 0s - loss: 0.0073 - mae: 0.0543 - mse: 0.0068 - rmse: 0.0823
# Epoch 70: val_loss improved from 0.00659 to 0.00659, saving model to best_mlp_model.h5
# 281/281 [==============================] - 4s 13ms/step - loss: 0.0073 - mae: 0.0543 - mse: 0.0068 - rmse: 0.0824 - val_loss: 0.0066 - val_mae: 0.0453 - val_mse: 0.0060 - val_rmse: 0.0777 - lr: 1.9531e-06
# Epoch 71/100
# 279/281 [============================>.] - ETA: 0s - loss: 0.0073 - mae: 0.0543 - mse: 0.0068 - rmse: 0.0823
# Epoch 71: val_loss improved from 0.00659 to 0.00659, saving model to best_mlp_model.h5
# 281/281 [==============================] - 4s 13ms/step - loss: 0.0073 - mae: 0.0543 - mse: 0.0068 - rmse: 0.0823 - val_loss: 0.0066 - val_mae: 0.0453 - val_mse: 0.0060 - val_rmse: 0.0777 - lr: 1.9531e-06
# Epoch 72/100
# 279/281 [============================>.] - ETA: 0s - loss: 0.0074 - mae: 0.0544 - mse: 0.0068 - rmse: 0.0824
# Epoch 72: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 72: val_loss did not improve from 0.00659
# 281/281 [==============================] - 4s 13ms/step - loss: 0.0074 - mae: 0.0544 - mse: 0.0068 - rmse: 0.0824 - val_loss: 0.0066 - val_mae: 0.0453 - val_mse: 0.0060 - val_rmse: 0.0777 - lr: 1.9531e-06
# Epoch 73/100
# 279/281 [============================>.] - ETA: 0s - loss: 0.0073 - mae: 0.0543 - mse: 0.0068 - rmse: 0.0824
# Epoch 73: val_loss did not improve from 0.00659
# 281/281 [==============================] - 4s 12ms/step - loss: 0.0073 - mae: 0.0543 - mse: 0.0068 - rmse: 0.0824 - val_loss: 0.0066 - val_mae: 0.0453 - val_mse: 0.0060 - val_rmse: 0.0777 - lr: 1.0000e-06
# Epoch 74/100
# 277/281 [============================>.] - ETA: 0s - loss: 0.0073 - mae: 0.0544 - mse: 0.0068 - rmse: 0.0823
# Epoch 74: val_loss did not improve from 0.00659
# 281/281 [==============================] - 4s 13ms/step - loss: 0.0073 - mae: 0.0544 - mse: 0.0068 - rmse: 0.0823 - val_loss: 0.0066 - val_mae: 0.0453 - val_mse: 0.0060 - val_rmse: 0.0777 - lr: 1.0000e-06
# Epoch 75/100
# 276/281 [============================>.] - ETA: 0s - loss: 0.0073 - mae: 0.0544 - mse: 0.0068 - rmse: 0.0823
# Epoch 75: val_loss did not improve from 0.00659
# 281/281 [==============================] - 4s 13ms/step - loss: 0.0073 - mae: 0.0543 - mse: 0.0068 - rmse: 0.0823 - val_loss: 0.0066 - val_mae: 0.0453 - val_mse: 0.0060 - val_rmse: 0.0777 - lr: 1.0000e-06
# Epoch 76/100
# 276/281 [============================>.] - ETA: 0s - loss: 0.0073 - mae: 0.0543 - mse: 0.0068 - rmse: 0.0822
# Epoch 76: val_loss improved from 0.00659 to 0.00659, saving model to best_mlp_model.h5
# 281/281 [==============================] - 4s 13ms/step - loss: 0.0073 - mae: 0.0543 - mse: 0.0068 - rmse: 0.0822 - val_loss: 0.0066 - val_mae: 0.0452 - val_mse: 0.0060 - val_rmse: 0.0776 - lr: 1.0000e-06
# Epoch 77/100
# 279/281 [============================>.] - ETA: 0s - loss: 0.0073 - mae: 0.0544 - mse: 0.0068 - rmse: 0.0824
# Epoch 77: val_loss did not improve from 0.00659
# 281/281 [==============================] - 4s 13ms/step - loss: 0.0073 - mae: 0.0544 - mse: 0.0068 - rmse: 0.0824 - val_loss: 0.0066 - val_mae: 0.0453 - val_mse: 0.0060 - val_rmse: 0.0776 - lr: 1.0000e-06
# Epoch 78/100
# 279/281 [============================>.] - ETA: 0s - loss: 0.0074 - mae: 0.0545 - mse: 0.0068 - rmse: 0.0825
# Epoch 78: val_loss did not improve from 0.00659
# 281/281 [==============================] - 3s 12ms/step - loss: 0.0074 - mae: 0.0545 - mse: 0.0068 - rmse: 0.0825 - val_loss: 0.0066 - val_mae: 0.0454 - val_mse: 0.0060 - val_rmse: 0.0777 - lr: 1.0000e-06
# Epoch 79/100
# 274/281 [============================>.] - ETA: 0s - loss: 0.0073 - mae: 0.0544 - mse: 0.0068 - rmse: 0.0824
# Epoch 79: val_loss did not improve from 0.00659
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0073 - mae: 0.0544 - mse: 0.0068 - rmse: 0.0824 - val_loss: 0.0066 - val_mae: 0.0453 - val_mse: 0.0060 - val_rmse: 0.0777 - lr: 1.0000e-06
# Epoch 80/100
# 273/281 [============================>.] - ETA: 0s - loss: 0.0073 - mae: 0.0542 - mse: 0.0068 - rmse: 0.0823
# Epoch 80: val_loss improved from 0.00659 to 0.00659, saving model to best_mlp_model.h5
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0073 - mae: 0.0543 - mse: 0.0068 - rmse: 0.0823 - val_loss: 0.0066 - val_mae: 0.0452 - val_mse: 0.0060 - val_rmse: 0.0776 - lr: 1.0000e-06
# Epoch 81/100
# 273/281 [============================>.] - ETA: 0s - loss: 0.0073 - mae: 0.0543 - mse: 0.0068 - rmse: 0.0823
# Epoch 81: val_loss did not improve from 0.00659
# 281/281 [==============================] - 2s 6ms/step - loss: 0.0073 - mae: 0.0542 - mse: 0.0068 - rmse: 0.0823 - val_loss: 0.0066 - val_mae: 0.0453 - val_mse: 0.0060 - val_rmse: 0.0776 - lr: 1.0000e-06
# Epoch 82/100
# 273/281 [============================>.] - ETA: 0s - loss: 0.0073 - mae: 0.0543 - mse: 0.0068 - rmse: 0.0823
# Epoch 82: val_loss did not improve from 0.00659
# 281/281 [==============================] - 2s 6ms/step - loss: 0.0073 - mae: 0.0543 - mse: 0.0068 - rmse: 0.0823 - val_loss: 0.0066 - val_mae: 0.0453 - val_mse: 0.0060 - val_rmse: 0.0777 - lr: 1.0000e-06
# Epoch 83/100
# 277/281 [============================>.] - ETA: 0s - loss: 0.0073 - mae: 0.0543 - mse: 0.0068 - rmse: 0.0823
# Epoch 83: val_loss improved from 0.00659 to 0.00659, saving model to best_mlp_model.h5
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0073 - mae: 0.0543 - mse: 0.0068 - rmse: 0.0822 - val_loss: 0.0066 - val_mae: 0.0453 - val_mse: 0.0060 - val_rmse: 0.0776 - lr: 1.0000e-06
# Epoch 84/100
# 275/281 [============================>.] - ETA: 0s - loss: 0.0073 - mae: 0.0544 - mse: 0.0068 - rmse: 0.0823
# Epoch 84: val_loss improved from 0.00659 to 0.00659, saving model to best_mlp_model.h5
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0073 - mae: 0.0544 - mse: 0.0068 - rmse: 0.0823 - val_loss: 0.0066 - val_mae: 0.0453 - val_mse: 0.0060 - val_rmse: 0.0776 - lr: 1.0000e-06
# Epoch 85/100
# 274/281 [============================>.] - ETA: 0s - loss: 0.0073 - mae: 0.0543 - mse: 0.0068 - rmse: 0.0822
# Epoch 85: val_loss did not improve from 0.00659
# 281/281 [==============================] - 2s 6ms/step - loss: 0.0073 - mae: 0.0544 - mse: 0.0068 - rmse: 0.0823 - val_loss: 0.0066 - val_mae: 0.0453 - val_mse: 0.0060 - val_rmse: 0.0776 - lr: 1.0000e-06
# Epoch 86/100
# 280/281 [============================>.] - ETA: 0s - loss: 0.0073 - mae: 0.0543 - mse: 0.0068 - rmse: 0.0823
# Epoch 86: val_loss did not improve from 0.00659
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0073 - mae: 0.0543 - mse: 0.0068 - rmse: 0.0823 - val_loss: 0.0066 - val_mae: 0.0452 - val_mse: 0.0060 - val_rmse: 0.0776 - lr: 1.0000e-06
# Epoch 87/100
# 278/281 [============================>.] - ETA: 0s - loss: 0.0073 - mae: 0.0544 - mse: 0.0068 - rmse: 0.0822
# Epoch 87: val_loss did not improve from 0.00659
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0073 - mae: 0.0544 - mse: 0.0068 - rmse: 0.0823 - val_loss: 0.0066 - val_mae: 0.0453 - val_mse: 0.0060 - val_rmse: 0.0776 - lr: 1.0000e-06
# Epoch 88/100
# 277/281 [============================>.] - ETA: 0s - loss: 0.0073 - mae: 0.0544 - mse: 0.0068 - rmse: 0.0824
# Epoch 88: val_loss did not improve from 0.00659
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0073 - mae: 0.0544 - mse: 0.0068 - rmse: 0.0824 - val_loss: 0.0066 - val_mae: 0.0454 - val_mse: 0.0060 - val_rmse: 0.0776 - lr: 1.0000e-06
# Epoch 89/100
# 279/281 [============================>.] - ETA: 0s - loss: 0.0073 - mae: 0.0543 - mse: 0.0068 - rmse: 0.0822
# Epoch 89: val_loss improved from 0.00659 to 0.00658, saving model to best_mlp_model.h5
# 281/281 [==============================] - 2s 6ms/step - loss: 0.0073 - mae: 0.0543 - mse: 0.0068 - rmse: 0.0822 - val_loss: 0.0066 - val_mae: 0.0452 - val_mse: 0.0060 - val_rmse: 0.0776 - lr: 1.0000e-06
# Epoch 90/100
# 280/281 [============================>.] - ETA: 0s - loss: 0.0073 - mae: 0.0544 - mse: 0.0068 - rmse: 0.0824
# Epoch 90: val_loss did not improve from 0.00658
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0073 - mae: 0.0544 - mse: 0.0068 - rmse: 0.0824 - val_loss: 0.0066 - val_mae: 0.0453 - val_mse: 0.0060 - val_rmse: 0.0776 - lr: 1.0000e-06
# Epoch 91/100
# 276/281 [============================>.] - ETA: 0s - loss: 0.0073 - mae: 0.0543 - mse: 0.0068 - rmse: 0.0824
# Epoch 91: val_loss did not improve from 0.00658
# 281/281 [==============================] - 2s 6ms/step - loss: 0.0073 - mae: 0.0543 - mse: 0.0068 - rmse: 0.0824 - val_loss: 0.0066 - val_mae: 0.0453 - val_mse: 0.0060 - val_rmse: 0.0777 - lr: 1.0000e-06
# Epoch 92/100
# 276/281 [============================>.] - ETA: 0s - loss: 0.0073 - mae: 0.0544 - mse: 0.0068 - rmse: 0.0823
# Epoch 92: val_loss did not improve from 0.00658
# 281/281 [==============================] - 2s 6ms/step - loss: 0.0073 - mae: 0.0544 - mse: 0.0068 - rmse: 0.0823 - val_loss: 0.0066 - val_mae: 0.0453 - val_mse: 0.0060 - val_rmse: 0.0776 - lr: 1.0000e-06
# Epoch 93/100
# 278/281 [============================>.] - ETA: 0s - loss: 0.0073 - mae: 0.0543 - mse: 0.0068 - rmse: 0.0822
# Epoch 93: val_loss did not improve from 0.00658
# 281/281 [==============================] - 2s 6ms/step - loss: 0.0073 - mae: 0.0543 - mse: 0.0067 - rmse: 0.0821 - val_loss: 0.0066 - val_mae: 0.0452 - val_mse: 0.0060 - val_rmse: 0.0776 - lr: 1.0000e-06
# Epoch 94/100
# 275/281 [============================>.] - ETA: 0s - loss: 0.0073 - mae: 0.0544 - mse: 0.0068 - rmse: 0.0824
# Epoch 94: val_loss did not improve from 0.00658
# 281/281 [==============================] - 2s 6ms/step - loss: 0.0073 - mae: 0.0544 - mse: 0.0068 - rmse: 0.0824 - val_loss: 0.0066 - val_mae: 0.0454 - val_mse: 0.0060 - val_rmse: 0.0776 - lr: 1.0000e-06
# Epoch 95/100
# 276/281 [============================>.] - ETA: 0s - loss: 0.0073 - mae: 0.0543 - mse: 0.0068 - rmse: 0.0823
# Epoch 95: val_loss did not improve from 0.00658
# 281/281 [==============================] - 2s 6ms/step - loss: 0.0073 - mae: 0.0543 - mse: 0.0068 - rmse: 0.0823 - val_loss: 0.0066 - val_mae: 0.0452 - val_mse: 0.0060 - val_rmse: 0.0776 - lr: 1.0000e-06
# Epoch 96/100
# 279/281 [============================>.] - ETA: 0s - loss: 0.0074 - mae: 0.0544 - mse: 0.0068 - rmse: 0.0824
# Epoch 96: val_loss did not improve from 0.00658
# 281/281 [==============================] - 2s 6ms/step - loss: 0.0074 - mae: 0.0544 - mse: 0.0068 - rmse: 0.0824 - val_loss: 0.0066 - val_mae: 0.0454 - val_mse: 0.0060 - val_rmse: 0.0776 - lr: 1.0000e-06
# Epoch 97/100
# 280/281 [============================>.] - ETA: 0s - loss: 0.0073 - mae: 0.0543 - mse: 0.0068 - rmse: 0.0823
# Epoch 97: val_loss did not improve from 0.00658
# 281/281 [==============================] - 2s 6ms/step - loss: 0.0073 - mae: 0.0543 - mse: 0.0068 - rmse: 0.0823 - val_loss: 0.0066 - val_mae: 0.0454 - val_mse: 0.0060 - val_rmse: 0.0776 - lr: 1.0000e-06
# Epoch 98/100
# 279/281 [============================>.] - ETA: 0s - loss: 0.0073 - mae: 0.0543 - mse: 0.0068 - rmse: 0.0822
# Epoch 98: val_loss improved from 0.00658 to 0.00658, saving model to best_mlp_model.h5
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0073 - mae: 0.0543 - mse: 0.0068 - rmse: 0.0822 - val_loss: 0.0066 - val_mae: 0.0451 - val_mse: 0.0060 - val_rmse: 0.0776 - lr: 1.0000e-06
# Epoch 99/100
# 276/281 [============================>.] - ETA: 0s - loss: 0.0073 - mae: 0.0544 - mse: 0.0068 - rmse: 0.0823
# Epoch 99: val_loss did not improve from 0.00658
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0073 - mae: 0.0544 - mse: 0.0068 - rmse: 0.0823 - val_loss: 0.0066 - val_mae: 0.0452 - val_mse: 0.0060 - val_rmse: 0.0776 - lr: 1.0000e-06
# Epoch 100/100
# 280/281 [============================>.] - ETA: 0s - loss: 0.0073 - mae: 0.0542 - mse: 0.0068 - rmse: 0.0822
# Epoch 100: val_loss did not improve from 0.00658
# 281/281 [==============================] - 2s 6ms/step - loss: 0.0073 - mae: 0.0543 - mse: 0.0068 - rmse: 0.0822 - val_loss: 0.0066 - val_mae: 0.0452 - val_mse: 0.0060 - val_rmse: 0.0776 - lr: 1.0000e-06

# %%
test_results = mlp_model.evaluate(test_dataset, verbose=0)

print(f" TEST SET PERFORMANCE:")
print(f"   Loss (MSE): {test_results[0]:.6f}")
print(f"   MAE:        {test_results[1]:.4f}")
print(f"   MSE:        {test_results[2]:.6f}")
print(f"   RMSE:       {test_results[3]:.4f}")
# Out:
#  TEST SET PERFORMANCE:
#    Loss (MSE): 0.006522
#    MAE:        0.0449
#    MSE:        0.005964
#    RMSE:       0.0772

# %%
test_data_collected = test_transformed.select('features', 'large_ms').collect()
X_test = np.array([row['features'].toArray() for row in test_data_collected])
y_test = np.array([row['large_ms'] for row in test_data_collected])

# %%
y_pred = mlp_model.predict(X_test, batch_size=1024, verbose=0).flatten()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

test_mae = mean_absolute_error(y_test, y_pred)
test_rmse = np.sqrt(mean_squared_error(y_test, y_pred))
test_r2 = r2_score(y_test, y_pred)
test_mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100

# %%
print(f"   MAE:  {test_mae:.4f}")
print(f"   RMSE: {test_rmse:.4f}")
print(f"   R²:   {test_r2:.4f}")
print(f"   MAPE: {test_mape:.2f}%")
# Out:
#    MAE:  0.0449
#    RMSE: 0.0772
#    R²:   0.8832
#    MAPE: 9.34%

# %%
residuals = y_test - y_pred

# %%
sample_df = pd.DataFrame({
    'Actual': y_test[:20],
    'Predicted': y_pred[:20],
    'Error': residuals[:20],
    'Error %': (residuals[:20] / y_test[:20] * 100)
})
print(sample_df.to_string(index=True))
# Out:
#     Actual  Predicted     Error    Error %
# 0     0.85   0.863933 -0.013933  -1.639166
# 1     0.37   0.493771 -0.123771 -33.451699
# 2     0.26   0.391486 -0.131486 -50.571465
# 3     0.83   0.832111 -0.002111  -0.254395
# 4     0.66   0.656139  0.003861   0.584989
# 5     0.80   0.781189  0.018811   2.351350
# 6     0.98   0.984175 -0.004175  -0.426023
# 7     0.29   0.297447 -0.007447  -2.567991
# 8     0.44   0.464680 -0.024680  -5.609020
# 9     0.35   0.468565 -0.118565 -33.875608
# 10    0.44   0.443207 -0.003207  -0.728883
# 11    0.94   0.955282 -0.015282  -1.625704
# 12    0.35   0.546277 -0.196277 -56.079156
# 13    0.61   0.609341  0.000659   0.108048
# 14    0.67   0.574838  0.095162  14.203251
# 15    1.00   0.990198  0.009802   0.980240
# 16    0.55   0.553760 -0.003760  -0.683711
# 17    1.00   0.990901  0.009099   0.909871
# 18    0.41   0.674080 -0.264080 -64.409672
# 19    1.00   0.990857  0.009143   0.914311
